# %% [markdown]
# NAME_1: Marco <br>
# LAST-NAME_1: Introvigne <br>
# STUDENT-ID_1: 10750466 <br>
# NAME_2: Antonio <br>
# LAST-NAME_2: Urbano <br>
# STUDENT-ID_2: 10527285 <br>
# NAME_3: Enrico <br>
# LAST-NAME_3: Voltan <br>
# STUDENT-ID_3: 10525467 <br>
# LEADERBOARD NICKNAME: TLN (Three Little Neurons) <br>

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import numpy as np 
import pandas as pd
import os
import tensorflow as tf

# %%
SEED = 1234
tf.random.set_seed(SEED) 
np.random.seed(SEED)

cwd = os.getcwd()

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Data Augmentation

# %% [markdown]
# We first tried to train the network without data augmentation. Then we added most meaningfull parameter according to the dataset taking always in consideration the behaviour in order to avoid overfitting.
# This final setting is the one which gave us the best result.

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_data_gen = ImageDataGenerator(rotation_range=10,
                                    zoom_range=0.2,
                                    width_shift_range=0.2,
                                    height_shift_range=0.2,
                                    brightness_range=[0.1,0.4],
                                    horizontal_flip=True,
                                    fill_mode="nearest",
                                    rescale=1./255)

valid_data_gen = ImageDataGenerator(rescale=1./255)
test_data_gen = ImageDataGenerator(rescale=1./255)

# %%
import json
classes = {}
with open('/content/drive/My Drive/Kaggle_1/MaskDataset/train_gt.json') as json_file:
    classes = json.load(json_file)

# %%
dataset_dir = "/content/drive/My Drive/Kaggle_1/MaskDataset/training"
from PIL import Image
df = pd.DataFrame(columns={"name","class"})
classes_names = {
    0:"NOPERSON",
    1:"ALL",
    2:"SOMEONE"
}

for dirname, _, filenames in os.walk(dataset_dir):
    for filename in filenames:
      df2 = pd.DataFrame.from_dict({"name" : [filename], "class" : [classes_names[classes[filename]]]})   
      df = df.append( df2, ignore_index=True)
df
# Out:
#            name     class
# 0     16649.jpg  NOPERSON
# 1     16798.jpg  NOPERSON
# 2     16613.jpg  NOPERSON
# 3     16507.jpg  NOPERSON
# 4     16808.jpg  NOPERSON
# ...         ...       ...
# 5609  10868.jpg   SOMEONE
# 5610  11316.jpg       ALL
# 5611  11266.jpg   SOMEONE
# 5612  11186.jpg       ALL
# 5613  11133.jpg   SOMEONE
#
# [5614 rows x 2 columns]

# %% [markdown]
# # Training and Validation

# %% [markdown]
# We have done crossvalidation splitting the training dataset into training and validation set by keeping the first 5000 images for training and the remaining 614 for validation.
# We have done tuning on the image size parameter increasing it gradually.

# %%
img_h = 204
img_w = 204

train_gen = train_data_gen.flow_from_dataframe(
                                                    df[:5000],
                                                    directory=dataset_dir,
                                                    x_col="name",
                                                    y_col="class",
                                                    target_size=(img_h, img_w),
                                                    batch_size=16,
                                                    shuffle=True,
                                                    seed=SEED,
                                                    save_prefix="",
                                                    save_format="png",
                                                    subset=None,
                                                    interpolation="nearest"
                                                ) 

valid_gen = valid_data_gen.flow_from_dataframe(
                                                    df[5000:],
                                                    directory=dataset_dir,
                                                    x_col="name",
                                                    y_col="class",
                                                    target_size=(img_h, img_w),
                                                    batch_size=16,
                                                    shuffle=True,
                                                    seed=SEED,
                                                    save_prefix="",
                                                    save_format="png",
                                                    subset=None,
                                                    interpolation="nearest"
                                                )
# Out:
# Found 5000 validated image filenames belonging to 3 classes.
# Found 614 validated image filenames belonging to 3 classes.

# %%
num_classes = 3

train_dataset = tf.data.Dataset.from_generator(lambda: train_gen,
                                               output_types=(tf.float32, tf.float32),
                                               output_shapes=([None, img_h, img_w, 3], [None, num_classes]))
train_dataset = train_dataset.repeat()

valid_dataset = tf.data.Dataset.from_generator(lambda: valid_gen, 
                                               output_types=(tf.float32, tf.float32),
                                               output_shapes=([None, img_h, img_w, 3], [None, num_classes]))
valid_dataset = valid_dataset.repeat()

# %% [markdown]
# ## Architecture

# %% [markdown]
# This is the best network without transfer learning we were able to build after several attempts and it is better described in the report.

# %%
# Architecture

model = tf.keras.Sequential()

# Conv-Conv-Pooling
for i in range(2):
  model.add(tf.keras.layers.Conv2D(filters=128, 
                                   kernel_size=(3,3),
                                   strides=(1,1),
                                   padding='same',
                                   input_shape=[img_h, img_w, 3]))
  model.add(tf.keras.layers.ReLU())
  model.add(tf.keras.layers.Conv2D(filters=128, 
                                  kernel_size=(3,3),
                                  strides=(1,1),
                                  padding='same',
                                  input_shape=[img_h, img_w, 3]))
  model.add(tf.keras.layers.ReLU()
  model.add(tf.keras.layers.MaxPool2D(pool_size=(2, 2),
                                      strides = (2,2)))

#Conv-Pooling
for j in range(2)
  model.add(tf.keras.layers.Conv2D(filters=128, 
                                  kernel_size=(3,3),
                                  strides=(1,1),
                                  padding='same',
                                  input_shape=[img_h, img_w, 3]))
  model.add(tf.keras.layers.ReLU())
  model.add(tf.keras.layers.MaxPool2D(pool_size=(2, 2),
                                      strides = (2,2)))

# Classifier
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(units=512, activation='relu'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Dense(units=num_classes, activation='softmax'))

# %%
# Visualize 
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 204, 204, 128)     3584
# _________________________________________________________________
# re_lu_6 (ReLU)               (None, 204, 204, 128)     0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 204, 204, 128)     147584
# _________________________________________________________________
# re_lu_7 (ReLU)               (None, 204, 204, 128)     0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 102, 102, 128)     0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 102, 102, 128)     147584
# _________________________________________________________________
# re_lu_8 (ReLU)               (None, 102, 102, 128)     0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 102, 102, 128)     147584
# _________________________________________________________________
# re_lu_9 (ReLU)               (None, 102, 102, 128)     0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 51, 51, 128)       0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 51, 51, 128)       147584
# _________________________________________________________________
# re_lu_10 (ReLU)              (None, 51, 51, 128)       0
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 25, 25, 128)       0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 25, 25, 128)       147584
# _________________________________________________________________
# re_lu_11 (ReLU)              (None, 25, 25, 128)       0
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 12, 12, 128)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               9437696
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 512)               2048
# _________________________________________________________________
# dense_3 (Dense)              (None, 3)                 1539
# =================================================================
# Total params: 10,182,787
# Trainable params: 10,181,763
# Non-trainable params: 1,024
# _________________________________________________________________

# %% [markdown]
# ## Training Model

# %% [markdown]
# We tried several optimizer but the best one were Adam and SGD. We did tuning on the learning rate for both of optimizers, and the best result was with Adam with learning rate equal to 0.0001.

# %%
lr = 1e-4
model.compile(optimizer=tf.keras.optimizers.Adam(lr=lr),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# We tried different solutions to prevent overfitting (Early stopping, Dropout).
# We adopt the early stopping technique and changed the patiance several times.

# %%
# Early Stopping
callbacks = []
early_stop = True
if early_stop:
    es_callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)
    callbacks.append(es_callback)

# %%
model.fit(x=train_dataset,
          epochs=100,
          steps_per_epoch=len(train_gen),
          validation_data=valid_dataset,
          validation_steps=len(valid_gen),
          callbacks=callbacks)
# Out:
# Epoch 1/100
# 200/200 [==============================] - ETA: 0s - loss: 1.1009 - accuracy: 0.3458WARNING:tensorflow:From <ipython-input-19-2492aac2d56d>:40: Model.predict_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.predict, which supports generators.
# 200/200 [==============================] - 144s 722ms/step - loss: 1.1009 - accuracy: 0.3458 - val_loss: 1.0992 - val_accuracy: 0.2818
# Epoch 2/100
# 200/200 [==============================] - 143s 715ms/step - loss: 1.0916 - accuracy: 0.3724 - val_loss: 1.0833 - val_accuracy: 0.3795
# Epoch 3/100
# 200/200 [==============================] - 143s 716ms/step - loss: 1.0723 - accuracy: 0.4182 - val_loss: 1.0277 - val_accuracy: 0.4544
# Epoch 4/100
# 200/200 [==============================] - 140s 701ms/step - loss: 1.0264 - accuracy: 0.4678 - val_loss: 1.2273 - val_accuracy: 0.4902
# Epoch 5/100
# 200/200 [==============================] - 138s 692ms/step - loss: 0.9623 - accuracy: 0.5214 - val_loss: 1.1180 - val_accuracy: 0.5700
# Epoch 6/100
# 200/200 [==============================] - 138s 692ms/step - loss: 0.8791 - accuracy: 0.5726 - val_loss: 0.8179 - val_accuracy: 0.6336
# Epoch 7/100
# 200/200 [==============================] - 138s 689ms/step - loss: 0.8266 - accuracy: 0.5940 - val_loss: 2.2981 - val_accuracy: 0.4023
# Epoch 8/100
# 200/200 [==============================] - 139s 696ms/step - loss: 0.7814 - accuracy: 0.6314 - val_loss: 0.7718 - val_accuracy: 0.6694
# Epoch 9/100
# 200/200 [==============================] - 144s 722ms/step - loss: 0.7273 - accuracy: 0.6512 - val_loss: 2.0685 - val_accuracy: 0.4691
# Epoch 10/100
# 200/200 [==============================] - 138s 691ms/step - loss: 0.7237 - accuracy: 0.6450 - val_loss: 1.1393 - val_accuracy: 0.6205
# Epoch 11/100
# 200/200 [==============================] - 138s 689ms/step - loss: 0.6816 - accuracy: 0.6730 - val_loss: 0.8979 - val_accuracy: 0.6743
# Epoch 12/100
# 200/200 [==============================] - 137s 685ms/step - loss: 0.6658 - accuracy: 0.6764 - val_loss: 1.1579 - val_accuracy: 0.6336
# Epoch 13/100
# 200/200 [==============================] - 140s 698ms/step - loss: 0.6417 - accuracy: 0.7008 - val_loss: 0.8903 - val_accuracy: 0.7003
# Epoch 14/100
# 200/200 [==============================] - 142s 709ms/step - loss: 0.6347 - accuracy: 0.7004 - val_loss: 1.3512 - val_accuracy: 0.5847
# Epoch 15/100
# 200/200 [==============================] - 141s 705ms/step - loss: 0.6053 - accuracy: 0.7090 - val_loss: 0.9904 - val_accuracy: 0.6303
# Epoch 16/100
# 200/200 [==============================] - 138s 688ms/step - loss: 0.6038 - accuracy: 0.7182 - val_loss: 0.6221 - val_accuracy: 0.7313
# Epoch 17/100
# 200/200 [==============================] - 141s 703ms/step - loss: 0.5711 - accuracy: 0.7222 - val_loss: 0.6784 - val_accuracy: 0.7085
# Epoch 18/100
# 200/200 [==============================] - 141s 703ms/step - loss: 0.5495 - accuracy: 0.7468 - val_loss: 0.5308 - val_accuracy: 0.7573
# Epoch 19/100
# 200/200 [==============================] - 145s 725ms/step - loss: 0.5465 - accuracy: 0.7524 - val_loss: 0.6074 - val_accuracy: 0.7394
# Epoch 20/100
# 200/200 [==============================] - 146s 732ms/step - loss: 0.5321 - accuracy: 0.7526 - val_loss: 0.6229 - val_accuracy: 0.7704
# Epoch 21/100
# 200/200 [==============================] - 144s 722ms/step - loss: 0.5295 - accuracy: 0.7662 - val_loss: 1.8526 - val_accuracy: 0.5358
# Epoch 22/100
# 200/200 [==============================] - 139s 697ms/step - loss: 0.5060 - accuracy: 0.7734 - val_loss: 0.7449 - val_accuracy: 0.7378
# Epoch 23/100
# 200/200 [==============================] - 147s 735ms/step - loss: 0.4943 - accuracy: 0.7742 - val_loss: 1.4079 - val_accuracy: 0.5651
# Epoch 24/100
# 200/200 [==============================] - 147s 736ms/step - loss: 0.4976 - accuracy: 0.7758 - val_loss: 0.5978 - val_accuracy: 0.7638
# Epoch 25/100
# 200/200 [==============================] - 151s 755ms/step - loss: 0.4795 - accuracy: 0.7818 - val_loss: 0.5378 - val_accuracy: 0.7508
# Epoch 26/100
# 200/200 [==============================] - 154s 772ms/step - loss: 0.4649 - accuracy: 0.7836 - val_loss: 0.6414 - val_accuracy: 0.7704
# Epoch 27/100
# 200/200 [==============================] - 148s 741ms/step - loss: 0.4712 - accuracy: 0.7884 - val_loss: 0.4783 - val_accuracy: 0.7850
# Epoch 28/100
# 200/200 [==============================] - 149s 743ms/step - loss: 0.4640 - accuracy: 0.7902 - val_loss: 0.7097 - val_accuracy: 0.7329
# Epoch 29/100
# 200/200 [==============================] - 148s 742ms/step - loss: 0.4555 - accuracy: 0.7920 - val_loss: 0.4984 - val_accuracy: 0.7883
# Epoch 30/100
# 200/200 [==============================] - 149s 745ms/step - loss: 0.4358 - accuracy: 0.8016 - val_loss: 0.6186 - val_accuracy: 0.7166
# Epoch 31/100
# 200/200 [==============================] - 149s 743ms/step - loss: 0.4458 - accuracy: 0.7990 - val_loss: 0.8137 - val_accuracy: 0.6612
# Epoch 32/100
# 200/200 [==============================] - 147s 733ms/step - loss: 0.4298 - accuracy: 0.8096 - val_loss: 0.4930 - val_accuracy: 0.7948
# Epoch 33/100
# 200/200 [==============================] - 143s 717ms/step - loss: 0.4231 - accuracy: 0.8146 - val_loss: 0.6367 - val_accuracy: 0.7378
# Epoch 34/100
# 200/200 [==============================] - 142s 712ms/step - loss: 0.3964 - accuracy: 0.8262 - val_loss: 0.5747 - val_accuracy: 0.7606
# Epoch 35/100
# 200/200 [==============================] - 141s 707ms/step - loss: 0.4076 - accuracy: 0.8158 - val_loss: 0.8696 - val_accuracy: 0.7541
# Epoch 36/100
# 200/200 [==============================] - 142s 711ms/step - loss: 0.4139 - accuracy: 0.8146 - val_loss: 0.5850 - val_accuracy: 0.7622
# Epoch 37/100
# 200/200 [==============================] - 138s 691ms/step - loss: 0.3988 - accuracy: 0.8206 - val_loss: 0.5402 - val_accuracy: 0.7655

# %% [markdown]
# ## Test

# %%
test_dir = "/content/drive/My Drive/Kaggle_1/MaskDataset/test_images/"

# %%
test_gen = test_data_gen.flow_from_directory(test_dir,
                                             batch_size=8, 
                                             target_size=(img_h, img_w),
                                             class_mode='categorical',
                                             shuffle=False,
                                             seed=SEED)

test_dataset = tf.data.Dataset.from_generator(lambda: test_gen,
                                              output_types=(tf.float32, tf.float32),
                                              output_shapes=([None, img_h, img_w, 3], None))
# Out:
# Found 450 images belonging to 1 classes.

# %%
eval_out = model.predict(x=test_dataset,
                          steps=len(test_gen),
                          verbose=0)
eval_out
# Out:
# array([[7.6152164e-01, 4.9786750e-06, 2.3847336e-01],
#        [2.6056604e-03, 4.2759824e-01, 5.6979603e-01],
#        [9.8858917e-01, 3.7545960e-06, 1.1407030e-02],
#        ...,
#        [1.6364202e-01, 1.1777764e-03, 8.3518016e-01],
#        [3.0051518e-05, 9.9900430e-01, 9.6570019e-04],
#        [2.8314272e-01, 2.8652452e-02, 6.8820482e-01]], dtype=float32)

# %%
label_map = (train_gen.class_indices)

map_cat = {v: k for k, v in label_map.items()}

real_names = {v: k for k, v in classes_names.items()}

results = {}
for i,name in enumerate(test_gen.filenames):
  real_name = name.split("/")[1]
  category = map_cat[np.argmax(eval_out[i])]
  results[real_name] = real_names[category]

results
# Out:
# {'10001.jpg': 1,
#  '10040.jpg': 2,
#  '10074.jpg': 1,
#  '10084.jpg': 1,
#  '10100.jpg': 2,
#  '10120.jpg': 2,
#  '10125.jpg': 1,
#  '10148.jpg': 1,
#  '10213.jpg': 1,
#  '10239.jpg': 1,
#  '10242.jpg': 1,
#  '10259.jpg': 1,
#  '10289.jpg': 2,
#  '10296.jpg': 0,
#  '10323.jpg': 2,
#  '10324.jpg': 0,
#  '14230.jpg': 1,
#  '14264.jpg': 1,
#  '14314.jpg': 2,
#  '14327.jpg': 2,
#  '14391.jpg': 0,
#  '14403.jpg': 2,
#  '14404.jpg': 1,
#  '14412.jpg': 1,
#  '14422.jpg': 1,
#  '14435.jpg': 0,
#  '14466.jpg': 2,
#  '14491.jpg': 2,
#  '14514.jpg': 1,
#  '14533.jpg': 2,
#  '14541.jpg': 1,
#  '14543.jpg': 0,
#  '14548.jpg': 2,
#  '14554.jpg': 1,
#  '14619.jpg': 0,
#  '14626.jpg': 2,
#  '14648.jpg': 1,
#  '14655.jpg': 0,
#  '14658.jpg': 0,
#  '14726.jpg': 2,
#  '14729.jpg': 1,
#  '14740.jpg': 1,
#  '14742.jpg': 0,
#  '14760.jpg': 2,
#  '14767.jpg': 0,
#  '14779.jpg': 1,
#  '14780.jpg': 0,
#  '14790.jpg': 1,
#  '14842.jpg': 0,
#  '14864.jpg': 0,
#  '14932.jpg': 2,
#  '14956.jpg': 1,
#  '14981.jpg': 2,
#  '14984.jpg': 1,
#  '14993.jpg': 0,
#  '15010.jpg': 0,
#  '15017.jpg': 2,
#  '15040.jpg': 2,
#  '15043.jpg': 2,
#  '15050.jpg': 0,
#  '15062.jpg': 0,
#  '15116.jpg': 0,
#  '15119.jpg': 1,
#  '15135.jpg': 2,
#  '15159.jpg': 1,
#  '15190.jpg': 0,
#  '15231.jpg': 0,
#  '15238.jpg': 0,
#  '15240.jpg': 2,
#  '15242.jpg': 1,
#  '15244.jpg': 0,
#  '15247.jpg': 2,
#  '15292.jpg': 2,
#  '15341.jpg': 0,
#  '15356.jpg': 1,
#  '15359.jpg': 2,
#  '15365.jpg': 0,
#  '15371.jpg': 0,
#  '15419.jpg': 2,
#  '15422.jpg': 2,
#  '15423.jpg': 2,
#  '15482.jpg': 2,
#  '15498.jpg': 1,
#  '15505.jpg': 2,
#  '15509.jpg': 1,
#  '15532.jpg': 0,
#  '15539.jpg': 1,
#  '15625.jpg': 2,
#  '15641.jpg': 0,
#  '15644.jpg': 0,
#  '15660.jpg': 0,
#  '15661.jpg': 0,
#  '15700.jpg': 1,
#  '15710.jpg': 1,
#  '15737.jpg': 1,
#  '15782.jpg': 1,
#  '15824.jpg': 2,
#  '15851.jpg': 0,
#  '15855.jpg': 1,
#  '15867.jpg': 1,
#  '15872.jpg': 0,
#  '15910.jpg': 2,
#  '15918.jpg': 2,
#  '15940.jpg': 1,
#  '15953.jpg': 0,
#  '15956.jpg': 0,
#  '16006.jpg': 1,
#  '16019.jpg': 0,
#  '16024.jpg': 2,
#  '16052.jpg': 2,
#  '16065.jpg': 1,
#  '16071.jpg': 0,
#  '16192.jpg': 2,
#  '16195.jpg': 1,
#  '16253.jpg': 1,
#  '16259.jpg': 1,
#  '16276.jpg': 0,
#  '16278.jpg': 0,
#  '16324.jpg': 2,
#  '16325.jpg': 0,
#  '16330.jpg': 2,
#  '16336.jpg': 0,
#  '16337.jpg': 1,
#  '16348.jpg': 2,
#  '16356.jpg': 2,
#  '16392.jpg': 0,
#  '16426.jpg': 0,
#  '16446.jpg': 2,
#  '16470.jpg': 2,
#  '16505.jpg': 1,
#  '16570.jpg': 1,
#  '16591.jpg': 0,
#  '16610.jpg': 0,
#  '16628.jpg': 1,
#  '16682.jpg': 0,
#  '16717.jpg': 1,
#  '16719.jpg': 0,
#  '16748.jpg': 2,
#  '16761.jpg': 2,
#  '16779.jpg': 0,
#  '16793.jpg': 1,
#  '16826.jpg': 2,
#  '16831.jpg': 0,
#  '16837.jpg': 1,
#  '16843.jpg': 2,
#  '16850.jpg': 0,
#  '16853.jpg': 1,
#  '16888.jpg': 0,
#  '16906.jpg': 1,
#  '16911.jpg': 1,
#  '16920.jpg': 1,
#  '16930.jpg': 2,
#  '16956.jpg': 1,
#  '16966.jpg': 1,
#  '16971.jpg': 0,
#  '16999.jpg': 2,
#  '17052.jpg': 0,
#  '17055.jpg': 2,
#  '17078.jpg': 1,
#  '17108.jpg': 0,
#  '17116.jpg': 0,
#  '17130.jpg': 2,
#  '17153.jpg': 1,
#  '17156.jpg': 2,
#  '17164.jpg': 0,
#  '17223.jpg': 2,
#  '17229.jpg': 1,
#  '17236.jpg': 2,
#  '17278.jpg': 0,
#  '17294.jpg': 1,
#  '17318.jpg': 0,
#  '17319.jpg': 2,
#  '17338.jpg': 1,
#  '17363.jpg': 2,
#  '17392.jpg': 2,
#  '17404.jpg': 1,
#  '17415.jpg': 2,
#  '17422.jpg': 0,
#  '17424.jpg': 1,
#  '17427.jpg': 1,
#  '17468.jpg': 0,
#  '17475.jpg': 1,
#  '17492.jpg': 0,
#  '17498.jpg': 0,
#  '17512.jpg': 2,
#  '17514.jpg': 1,
#  '17520.jpg': 1,
#  '17523.jpg': 1,
#  '17524.jpg': 1,
#  '17530.jpg': 2,
#  '17532.jpg': 2,
#  '17536.jpg': 2,
#  '17557.jpg': 1,
#  '17566.jpg': 0,
#  '17598.jpg': 2,
#  '17636.jpg': 1,
#  '17649.jpg': 2,
#  '17692.jpg': 2,
#  '17715.jpg': 0,
#  '17743.jpg': 1,
#  '17744.jpg': 0,
#  '17755.jpg': 2,
#  '17758.jpg': 2,
#  '17762.jpg': 2,
#  '17773.jpg': 0,
#  '17803.jpg': 2,
#  '17816.jpg': 1,
#  '17855.jpg': 0,
#  '17864.jpg': 2,
#  '17893.jpg': 2,
#  '17897.jpg': 1,
#  '17901.jpg': 0,
#  '17921.jpg': 1,
#  '17939.jpg': 1,
#  '17967.jpg': 1,
#  '17983.jpg': 2,
#  '18000.jpg': 1,
#  '18029.jpg': 1,
#  '18049.jpg': 2,
#  '18063.jpg': 1,
#  '18067.jpg': 0,
#  '18078.jpg': 1,
#  '18099.jpg': 2,
#  '18102.jpg': 0,
#  '18123.jpg': 2,
#  '18125.jpg': 1,
#  '18153.jpg': 2,
#  '18162.jpg': 0,
#  '18203.jpg': 2}

# %% [markdown]
# ## Kaggle Result

# %%
#Kaggle Result

import os
from datetime import datetime

def create_csv(results, results_dir='./'):

    csv_fname = 'results_'
    csv_fname += datetime.now().strftime('%b%d_%H-%M-%S') + '.csv'

    with open(os.path.join(results_dir, csv_fname), 'w') as f:

        f.write('Id,Category\n')

        for key, value in results.items():
            f.write(key + ',' + str(value) + '\n')

# %%
create_csv(results,"/content/drive/My Drive/Keras3")

# %% [markdown]
# FINISH!
